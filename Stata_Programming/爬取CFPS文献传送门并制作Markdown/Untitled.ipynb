# %%
import pandas as pd
import requests
import html2text as ht

# %%
df = pd.read_stata("allList.dta")

# %%
df['link'][0]
# Out:
# 'http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/../../xzyj/wxzsm/1295352.htm'

# %%
df
# Out:
#                                      title  \
# 0      CFPS小课堂 | 个个网红脸，傻傻分不清，说说CFPS中那些家庭收入
# 1               CFPS小课堂 | 职业编码炼成记之二：职业地位指标
# 2                     用户交流会资料分享 | CFPS量表介绍
# 3                         CFPS小课堂 | 支出综合变量
# 4                 用户交流会资料分享 | CFPS数据服务更新介绍
# 5                      CFPS小课堂 | 如何计算兄弟姐妹数
# 6            用户交流会资料分享 | CFPS数据更新介绍及用户常见问题
# 7                     CFPS小课堂 | 父母SES的综合变量
# 8                    CFPS小课堂 | 职业编码是如何炼成的？
# 9     CFPS小课堂 | 请不要问我，我“不知道”，我“拒绝回答”......
# 10              CFPS小课堂 | 还在为清理变量费神？试试综合变量
# 11           CFPS小课堂 | 城里人vs.农村人，城乡界定谁说了算？
# 12                          CFPS小课堂 | 人员类型
# 13                      CFPS小课堂 | 2016电访先行
# 14                          CFPS小课堂 | 地址信息
# 15                       CFPS小课堂 | 家庭成员的定义
# 16           CFPS小课堂 | 职业编码炼成记之三：职业地位指标养成法
# 17                  CFPS小课堂 | CFPS的正确打开方式
# 18  CFPS小课堂 | 穿过大半个中国去寻你：如何在CFPS数据中界定流动人口
# 19                用户交流会资料分享 | CFPS权数使用常见问题
# 20             用户交流会资料分享 | CFPS中EHC的设计与应用
# 21                CFPS小课堂 | CFPS中的认知测试（上）
# 22                 CFPS小课堂 | CFPS中的认知测试（下）
# 23                      CFPS小课堂 | 数据使用 Q&A
# 24          CFPS小课堂 | 家庭变迁与追踪调查 • 用户手册篇（一）
# 25          CFPS小课堂 | 家庭变迁与追踪调查 • 用户手册篇（二）
# 26         CFPS小课堂 | 怎样调查家庭收入？（上）· 用户手册（三）
# 27        CFPS小课堂 | 怎样调查家庭收入？（中）· 用户手册篇（四）
# 28         CFPS小课堂 | 怎样调查家庭收入？（下）·用户手册篇（五）
# 29            CFPS小课堂 | 如何调查家庭支出？·用户手册篇（六）
# 30             CFPS小课堂 | 计算家庭财产 · 用户手册篇（七）
# 31    CFPS小课堂 | 如何采集人们受教育程度的信息? · 用户手册篇(八)
# 32     CFPS小课堂 | 如何对形形色色的方言进行编码 · 用户手册篇(九)
# 33                       CFPS小课堂 | 权数使用Q&A
# 34           CFPS小课堂 | 个人问卷设计思路 · 用户手册篇（十）
# 35        CFPS小课堂 | 工作模块的设计与更新 · 用户手册篇（十一）
# 36       CFPS小课堂 | 我能申请使用CFPS样本的区县名或国标码么？
# 37                      CFPS小课堂 | 家庭收入你问我答
# 38               CFPS小课堂 | CFPS个人收入，你了解多少？
# 39                  CFPS小课堂 | EHC工作模块的示例解读
# 40                     CFPS小课堂 | 少儿问卷跨年对照表
# 41                  CFPS小课堂 | CFPS失业率的计算方法
# 42             CFPS小课堂 | CFPS数据中有没有“户主”信息？
# 43                     CFPS小课堂 | 婚姻模块的逻辑跳转
# 44                 CFPS小课堂 | 今天给你一套心理量表锦囊
# 45               CFPS小课堂 | 神器推荐：问卷跨年对照表更新
# 46               CFPS小课堂 | 数据使用Q&A（2020：1）
# 47               CFPS小课堂 | 数据使用Q&A（2020：2）
#
#                                                  link
# 0   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/....
# 1   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 2   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 3   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 4   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 5   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 6   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 7   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 8   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 9   http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 10  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 11  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 12  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 13  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 14  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 15  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 16  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 17  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 18  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 19  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 20  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 21  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 22  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 23  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 24  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 25  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 26  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 27  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 28  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 29  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 30  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 31  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 32  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 33  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 34  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 35  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 36  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 37  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 38  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 39  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 40  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 41  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 42  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 43  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 44  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 45  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 46  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...
# 47  http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1...

# %%
config = pdfkit.configuration(
    wkhtmltopdf=r"C:\Program Files\wkhtmltopdf\bin\wkhtmltopdf.exe")
try:
    pdfkit.from_url('http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1323239.htm',
                    'out.pdf', configuration=config)
except:
    pass

# %%
# 转为 MarkDown
link ="http://www.isss.pku.edu.cn/cfps/cjwt/cfpsxkt/1295323.htm"

html = requests.get(link)
html.encoding = 'utf8'
md = ht.html2text(html.text)
md = md.split("##")
type(md)

# 写入文件
with open("1.md","w") as f:
    for row in range(3,len(md)):
        f.write(md[row])

# %%
import requests
import html2text as ht

title = Data.get(var='title')
links = Data.get(var='link')


for i in range(len(link)):
    html = requests.get(link[i])
    html.encoding = 'utf8'
    md = ht.html2text(html.text)

    with open(title[i], "w") as f:
        for row in range(3, len(md)):
            f.write(md[row])

# %%
import html2text as ht
import requests
python:

title = Data.get(var='title')
title2 = Data.get(var='title2')
links = Data.get(var='link')

for i in range(len(links)):
    html = requests.get(links[i])
    html.encoding = 'utf8'
    md = ht.html2text(html.text)
    md = md.split("##")
    filepath = title2[i] + ".md"

    with open(filepath, "w", encoding='utf8') as f:
        for row in range(3, len(md)):
            f.write(md[row])
end
