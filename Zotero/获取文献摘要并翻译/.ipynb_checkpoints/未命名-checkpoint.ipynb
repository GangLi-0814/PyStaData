# %%
from pyzotero import zotero
import pandas as pd
import requests
import random
import json
from hashlib import md5

# %% [markdown]
# ## 百度翻译API

# %%
# 百度翻译API
appid = "20210308000719746" #自己申请的 appid
appkey = "wRJ1Nk3ZyDNDwYVAMZW_" # 自己申请的 key

# %%
# 调用百度翻译 API
def make_md5(s, encoding='utf-8'):
    '''
    生成随机数和签名
    '''
    return md5(s.encode(encoding)).hexdigest()

def translate(query, from_lang, to_lang):
    '''
    调用百度翻译 API
    '''
    url = 'http://api.fanyi.baidu.com/api/trans/vip/translate'
    salt = random.randint(1, 65536) #随机数
    sign = make_md5(appid + query + str(salt) + appkey)

    # 构造请求
    headers = {'Content-Type': 'application/x-www-form-urlencoded'}
    payload = {'appid': appid,
               'q': query,
               'from': from_lang,
               'to': to_lang,
               'salt': salt,
               'sign': sign
              }
    r = requests.post(url, params=payload, headers=headers)
    text = r.json()
    result = text['trans_result'][0]['dst']
    return result

# %% [markdown]
# ## Zotero操作

# %%
# Zotero账户
library_id = '7181737' # https://www.zotero.org/settings/keys
library_type = 'user' # 'user' or 'group'
api_key = 'DxrU57uh7D9Ii24XxUHOraee' #  not be accessible again after created.

# %%
zot = zotero.Zotero(library_id, library_type, api_key)
colls = zot.collections() # 所有集合名称

# %%
# 查找待分析的集合
for coll in colls:
    if coll['data']['name'] == 'Environment':
        print(coll)
# Out:
# {'key': '9FLNCCHU', 'version': 5294, 'library': {'type': 'user', 'id': 7181737, 'name': 'Gang_Li_ZUEL', 'links': {'alternate': {'href': 'https://www.zotero.org/gang_li_zuel', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/7181737/collections/9FLNCCHU', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/gang_li_zuel/collections/9FLNCCHU', 'type': 'text/html'}, 'up': {'href': 'https://api.zotero.org/users/7181737/collections/KXZ975FD', 'type': 'application/json'}}, 'meta': {'numCollections': 0, 'numItems': 65}, 'data': {'key': '9FLNCCHU', 'version': 5294, 'name': 'Environment', 'parentCollection': 'KXZ975FD', 'relations': {}}}

# %%
pyz = zot.collection_items('9FLNCCHU') # 待分析集合的key

# %%
# pyz[65]['data'] #'itemType': 'attachment'
# pyz[99]['data'] #'itemType': 'journalArticle'

# %%
# 存储标题、摘要和作者
title = []
abstract = []
author = []   
for p in pyz:
    if p['data']['itemType'] == "journalArticle":
        title.append(p['data']['title'])
        abstract.append(p['data']['abstractNote'])
        author.append(p['data']['creators'][0]['lastName'])

# %%
# 翻译成中文
abstract_cn = []
for ab in abstract:
    if ab != "":
        abstract_cn.append(translate(ab,"en","zh"))
    else:
        abstract_cn.append("")

# %%
# 写入DataFrame
paper_info = {
    "title": title,
    "author": author,
    "abstract": abstract,
    "abstract_cn":abstract_cn
}
df = pd.DataFrame(paper_info)

# 导出为Excel
df.to_excel("Environment_References_Abstract_CN.xlsx", index=None)

# 11  This paper draws on a natural experiment gener...
# 12  This paper examines whether US gasoline conten...
# 13  We link daily air pollution exposure to measur...
# 14  Developing countries, including China, are jus...
# 15  This paper analyzes hybrid emissions trading s...
# 16  We combine a theoretical discrete-choice model...
# 17  This article studies the introduction of an EU...
# 18  Between 1990 and 2008, air pollution emissions...
# 19  We analyze optimal pollution standards and enf...
# 20  Major cities in China and many other fast-grow...
# 21  We propose informational spillovers as a new r...
# 22  The SARS-COV-2 virus, also known as the corona...
# 23  We evaluate the pollution and labor supply red...
# 24  This paper examines the causal relationship be...
# 25  First-best pricing or assignment of property r...
# 26  This paper evaluates the real effects of envir...
# 27  We use a residential sorting model incorporati...
# 28  This paper analyzes the eﬀects of environmenta...
# 29  Individuals take preventive measures to avoid ...
# 30  We provide ﬁrst evidence of a link from daily ...
# 31  Abatement expenditures are not the only availa...
# 32  Although market-based environmental policy ins...
# 33  In many developing countries, environmental qu...
# 34
# 35  The demand for air quality depends on health i...
# 36
# 37  This study presents a framework to include env...
# 38  This paper uses newly available data on plant ...
# 39  We provide the ﬁrst study estimating the causa...
# 40  This paper studies the consequences of China's...
# 41  We analyze a transboundary pollution different...
# 42  The Porter Hypothesis (PH) posits that well-de...
# 43  This paper studies how the pollution reduction...
# 44  Different political parties place different va...
# 45  This paper uses individual-level data to estim...
#
#                                           abstract_cn
# 0   本文使用中国水质监测系统中隐含的空间回归不连续设计，评估了环境监管对企业生产率的影响。由于水...
# 1   本文描述了一个新的事实，然后分析了其原因和后果：在大多数国家，肮脏行业的进口关税和非关税壁垒...
# 2   本文考察了1991-2012年中国收入、污染和死亡率之间的关系。利用第一差分模型，我们证明了...
# 3
# 4
# 5   我们根据市场启动前的可用信息，研究加州温室气体总量管制与交易市场的潜在均衡。我们发现，照常营...
# 6
# 7   利用迄今为止汇编的关于空气和水污染及环境法规的最全面的发展中国家数据集，本文评估了印度在设计...
# 8   我们使用医疗保险数据估计了急性细颗粒物暴露对美国老年人死亡率、医疗保健使用和医疗费用的因果影...
# 9   美国环境保护署（EPA）采用动态方法执行空气污染法规，屡犯者将被处以高额罚款，并被指定为高优...
# 10  对环境标准的间歇性监测可能导致污染活动的战略性变化。本文件记录了根据《联邦清洁空气法》对周期...
# 11  本文利用中国国家特别监管公司（NSMF）计划进行的一项自然实验，评估中央监管在改善地方环境执...
# 12  本文考察了美国汽油含量法规是否成功地减少了臭氧污染，该法规给消费者带来了巨大的成本。我们利用...
# 13  我们将日常空气污染暴露与加利福尼亚州12个最大机场周围社区的同期健康指标联系起来。这些机场是...
# 14  包括中国在内的发展中国家刚刚开始思考如何在经济发展与解决众多严重环境问题的愿望之间取得平衡。...
# 15  本文分析了当企业减排成本和未来排放量不确定时，分区环境监管下的混合排放交易系统（ETS）。我...
# 16  我们结合了理论上的车辆购买离散选择模型、电力排放的计量经济学分析和AP2空气污染模型，以估算...
# 17  本文研究在汽车市场上引入欧盟范围内的排放标准。使用1998年至2011年的面板数据，我发现企...
# 18  1990年至2008年间，尽管制造业产出大幅增加，但美国制造业的空气污染排放量却下降了60%...
# 19  我们分析了环境损害取决于累积污染，且执行成本高的环境下的最佳污染标准和执行策略。我们假设监管...
# 20  中国的主要城市和许多其他快速发展的经济体正在扩建地铁系统，以解决日益恶化的空气污染和交通拥堵...
# 21  我们提出信息溢出作为使用多种政策工具来缓解单一外部性的新理由。当企业的减排成本未知且排放物被...
# 22  SARS-COV-2病毒，也称为冠状病毒，已经在全世界传播。越来越多的文献表明，接触污染会导...
# 23  我们评估了北京限制驾驶造成的污染和劳动力供应减少。从空气质量的时间序列和空间变化以及电视观众...
# 24  本文采用差异设计和回归不连续性分析，检验了中国燃料标准与空气污染之间的因果关系。结合各州实施...
# 25  竞争对手和非排他性商品的最优定价或产权转让通常是不可行的。在一个社会规划者不能限制总使用的环...
# 26  本文评估了环境司法改革对企业层面环境治理的实际影响。将在中国建立环境法院作为准自然实验，我们...
# 27  我们使用一个包含迁移不效用的居民分类模型来恢复中国清洁空气的隐含价值。该模型使用中国人口普查...
# 28  本文使用新的一般均衡两部门搜索模型分析了环境政策对就业（和失业）的影响。我们发现，征收污染税...
# 29  个人采取预防措施以避免代价高昂的空气污染暴露。本文为中国城市居民购买微粒过滤面罩以防止环境空...
# 30  在一组中国城市中，我们提供了日常空气污染暴露与睡眠不足之间联系的第一个证据。我们开发了一个基...
# 31  减排支出不是企业减少排放的唯一可用工具。技术选择也会间接影响环境绩效。我们评估进口竞争对植物...
# 32  尽管以市场为基础的环境政策工具在经济理论中占有突出地位并得到广泛应用，但它们往往面临公众的抵...
# 33  在许多发展中国家，环境质量仍然很低，改善环境质量的政策效果不一。我们对印度的环境政策进行了案...
# 34
# 35  对空气质量的需求取决于对健康的影响和防御投资，但很少有研究评估防御的经验重要性。丰富的准实验...
# 36
# 37  本研究提出了一个将环境外部性纳入国民账户体系的框架。这篇论文估计了美国各行业的空气污染损失。...
# 38  本文使用与人口普查纵向业务数据库相关的工厂层面监管现状的最新可用数据，测量县级环境监管变化对...
# 39  我们提供了第一项研究，评估了空气污染对体重和肥胖的因果影响。利用中国健康与营养调查（包含19...
# 40  本文研究了中国近期水污染管制的后果。我们发现有证据表明，该法规减少了高度监管地区的污染密集型...
# 41  我们分析了一个跨界污染微分博弈，其中污染控制在多个具有预定空间关系的代理之间进行空间分布。该...
# 42  波特假说（PH）认为，设计良好的环境法规可以刺激创新，从而提高效率，甚至增加受监管企业的利润...
# 43  本文研究了中国中央政府在2001年实施的污染减排任务如何引发各省的意外反应。我们将差异中的差...
# 44  不同的政党对环境有不同的价值观。在考虑两党民主制度和资本密集型技术时，我们发现前瞻性政府将失...
# 45  本文使用个人层面的数据来估计环境政策对劳动力市场的影响。以工人而非行业为分析单位，使我能够调...
